# %% [markdown]
# # Spoken Digit Classification
# <br/>
# <center>Francesco Di Salvo <br/> <i>Politecnico di Torino <br /> s282418@studenti.polito.it</i></center>
# <br />
#
#
# ## Abstract
#
# ## Data extraction

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
dev_df = pd.read_csv('../Datasets/NYC_Airbnb/development.csv')
eval_df = pd.read_csv('../Datasets/NYC_Airbnb/evaluation.csv')

# %% [markdown]
# ## EDA

# %%
dev_df.sample()
# Out:
#            id                                 name  host_id host_name  \
# 24551  254131  Read it 1st, A seprat fur BR, low $  1267021    Sharma
#
#       neighbourhood_group    neighbourhood  latitude  longitude     room_type  \
# 24551              Queens  Jackson Heights  40.74965  -73.89344  Private room
#
#        price  minimum_nights  number_of_reviews last_review  \
# 24551     54               5                 56  2019-07-06
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 24551               0.66                               3               365

# %% [markdown]
# It is clear that we are dealing with so many attributes and some of them can be considered redundant, in fact for example we have four geographical attributes (neighbourhood_group, neighborhood, latitude and longitude). So we should consider which ones of them are most related to the price and as a consequence we could avoid the other ones. But, in order to do so, we should convert the neighborourhood to categorical numerical values. It will also improve the model performance later on.

# %%
dev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39116 entries, 0 to 39115
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              39116 non-null  int64
#  1   name                            39103 non-null  object
#  2   host_id                         39116 non-null  int64
#  3   host_name                       39097 non-null  object
#  4   neighbourhood_group             39116 non-null  object
#  5   neighbourhood                   39116 non-null  object
#  6   latitude                        39116 non-null  float64
#  7   longitude                       39116 non-null  float64
#  8   room_type                       39116 non-null  object
#  9   price                           39116 non-null  int64
#  10  minimum_nights                  39116 non-null  int64
#  11  number_of_reviews               39116 non-null  int64
# ...

# %%
eval_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9779 entries, 0 to 9778
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              9779 non-null   int64
#  1   name                            9776 non-null   object
#  2   host_id                         9779 non-null   int64
#  3   host_name                       9777 non-null   object
#  4   neighbourhood_group             9779 non-null   object
#  5   neighbourhood                   9779 non-null   object
#  6   latitude                        9779 non-null   float64
#  7   longitude                       9779 non-null   float64
#  8   room_type                       9779 non-null   object
#  9   minimum_nights                  9779 non-null   int64
#  10  number_of_reviews               9779 non-null   int64
#  11  last_review                     7768 non-null   object
# ...

# %%
dev_df.isnull().sum()
# Out:
# id                                   0
# name                                13
# host_id                              0
# host_name                           19
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       8041
# reviews_per_month                 8041
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %% [markdown]
# The good idea is that there are not so many null values,

# %%
dev_df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'host_id'}>,
#         <AxesSubplot:title={'center':'latitude'}>],
#        [<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'price'}>,
#         <AxesSubplot:title={'center':'minimum_nights'}>],
#        [<AxesSubplot:title={'center':'number_of_reviews'}>,
#         <AxesSubplot:title={'center':'reviews_per_month'}>,
#         <AxesSubplot:title={'center':'calculated_host_listings_count'}>],
#        [<AxesSubplot:title={'center':'availability_365'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# There are several criticities with this current dataset. The first thing is that there are several nominal values that must be converted thanks to the one hot encoding. Then, the distribution are not so regular, in fact it can be noticed that some of them are concentrated in a short interval but there are several other bins. It means that there are few values on the external limits. Now let's discover the geographical distribution of these houses.

# %%
fig, axes = plt.subplots(1,2, figsize=(12,5))
dev_df.plot(kind="scatter", x="longitude", y="latitude", alpha=0.2,ax=axes[0])
eval_df.plot(kind="scatter", x="longitude", y="latitude", alpha=0.2,ax=axes[1])
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# There are portions of the metropolitan area where there is a huge presence of houses, so it can bias in some way the average price and eventually also the prediction. In order to gain other significant insights, we should look for correlations with the scatter matrix, provided by pandas.

# %%
from pandas.plotting import scatter_matrix
sns.set_style("dark")
attributes = ["price","latitude","longitude","number_of_reviews"]
axes = scatter_matrix(dev_df[attributes], figsize=(12,8))

for i in range(np.shape(axes)[0]):
    for j in range(np.shape(axes)[1]):
        if j > 0:
            axes[i,j].set_visible(False)

# %% [markdown]
# ## Data preprocessing

# %%
"""
    cleaning: 
        - drop id, name, host_name, last_review
        - fill reviews_per_month with its mean
        - convert categorical nominal into values, with Pandas
"""
def preprocess(df,kind):
    # eliminate unuseful attributes 
    df = df.drop(columns=["name","host_name","last_review"])

    # null values on review_per_month : fill with the average
    avg_reviews = df['reviews_per_month'].mean()
    df['reviews_per_month'].fillna(avg_reviews, inplace=True)

    # convert categorical nominal values into categorical numeric ones
    df['neighbourhood_group']= df['neighbourhood_group'].astype("category").cat.codes
    df['neighbourhood'] = df['neighbourhood'].astype("category").cat.codes
    df['room_type'] = df['room_type'].astype("category").cat.codes
    
    if kind == "dev":
        return df.drop(['price'], axis="columns"), df.price
    elif kind == "eval":
        return df

# %%
from sklearn.preprocessing import StandardScaler

X_dev, y_dev = preprocess(dev_df,"dev")
X_eval = preprocess(eval_df,"eval")

scaler_dev = StandardScaler()
scaler_eval = StandardScaler()

X_dev = scaler_dev.fit_transform(X_dev)
X_eval = scaler_eval.fit_transform(X_eval)

# %%
X_dev.shape, X_eval.shape
# Out:
# ((39116, 12), (9779, 12))

# %% [markdown]
# ## Model selection

# %%
## LINEAR REGRESSION ##
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV

def doLinearReg(in_X,in_y):
    
    model = LinearRegression()
    parameters = {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
    gs = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring='r2',
                         cv=5,
                         n_jobs=-1)

    ## Lastly, finding the best parameters.
    gs.fit(in_X, in_y)
    best_parameters_LR = gs.best_params_  
    best_score_LR = gs.best_score_ 
    print(best_parameters_LR)
    print(best_score_LR)

doLinearReg(X_dev,y_dev)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True}
# 0.09538565395694805

# %%
## RANDOM FOREST ##
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

def doRandomForest(in_X,in_y):
    
    model = RandomForestRegressor(n_jobs=-1)
    parameters = {
        'n_estimators':[100,200,400], 
        'max_depth':[100,200]
    }
    
    gs = GridSearchCV(estimator=model,  
                         param_grid=parameters,
                         scoring='r2',
                         cv=5,
                         n_jobs=-1)

    ## Lastly, finding the best parameters.
    gs.fit(in_X, in_y)
    best_parameters = gs.best_params_  
    best_score = gs.best_score_ 
    print(best_parameters)
    print(best_score)

    
doRandomForest(X_dev,y_dev)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dev,y_dev,test_size=0.3,random_state=42)

# %%
# I cannot use degree > 2
Poly = PolynomialFeatures(degree=3, interaction_only=True, include_bias=False)
X_train = Poly.fit_transform(X_train)
X_test = Poly.fit_transform(X_test)

# %%
## Linear Regression
lr = LinearRegression(copy_X = True, fit_intercept = True, normalize = False)
lr.fit(X_train, y_train)
lr_pred= lr.predict(X_test)

#Ridge Model
ridge_model = Ridge(alpha = 0.01, normalize = True)
ridge_model.fit(X_train, y_train)             
pred_ridge = ridge_model.predict(X_test) 

#Lasso Model
Lasso_model = Lasso(alpha = 0.001, normalize =False)
Lasso_model.fit(X_train, y_train)
pred_Lasso = Lasso_model.predict(X_test)
# Out:
# C:\Users\Francesco\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 735800888.6862129, tolerance: 172665.33057296675
#   positive)

# %%
print("LR\t\t: ",r2_score(y_test,lr_pred))
print("L\t\t: ",r2_score(y_test,pred_Lasso))
print("R\t\t: ",r2_score(y_test,pred_ridge))
# Out:
# LR		:  0.10594982048212653
# L		:  0.10591821132933388
# R		:  0.10790915088846442

# %%
"""from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import PolynomialFeatures

rf = RandomForestRegressor()
pipeline = make_pipeline(column_trans,PolynomialFeatures(5),rf)
c = cross_val_score(pipeline, X, y, cv=3, scoring='r2').mean()"""

# %% [markdown]
# ## Final evaluation

# %%
Poly = PolynomialFeatures(degree=1, interaction_only=True, include_bias=False)
X_dev = Poly.fit_transform(X_dev)
X_eval = Poly.fit_transform(X_eval)

# %%
X_dev.shape, X_eval.shape
# Out:
# ((39116, 11), (9779, 11))

# %%
lr = LinearRegression(copy_X = True, fit_intercept = True, normalize = False)
lr.fit(X_dev, y_dev)
price_prediction = lr.predict(X_eval)

# %%
price_prediction
# Out:
# array([147.69172319,  52.84063658,  78.01311793, ..., 161.20569786,
#         67.132392  ,  66.38136435])

# %% [markdown]
# ## CSV

# %%
pd.DataFrame(dict(Id = eval_df['id'],Predicted = price_prediction)).to_csv("submission.csv",sep=",",index=False)
